# %%
# %reset -f

# %%
import pandas as pd
from pathlib import Path
from sssom.parsers import parse_sssom_table

# %%
# Functions

def flip_predicate(predicate_id):
    flip_dict = {
        "skos:closeMatch": "skos:closeMatch",
        "skos:relatedMatch": "skos:relatedMatch",
        "skos:narrowMatch" : "skos:broadMatch",
        "skos:broadMatch" : "skos:narrowMatch",
        "skos:exactMatch" : "skos:exactMatch"
    }
    
    return flip_dict[predicate_id]

# %%
data_dir = Path("__file__").resolve().parents[1] / "data"
mondo_lexmatch_sssom = data_dir/ "mondo_lexmatch.sssom.tsv"

# %%
# %%time
mondo_lexmatch_df = parse_sssom_table(mondo_lexmatch_sssom)
mondo_lexmatch_df.df.head()
# Out:
# WARNING:root:Cannot automatically determine table format, trying tsv.
# CPU times: user 7min 20s, sys: 3.26 s, total: 7min 23s
# Wall time: 7min 25s
#                             subject_id subject_label     predicate_id  \
# 0  <http://identifiers.org/hgnc/10263>           RP1  skos:closeMatch
# 1  <http://identifiers.org/hgnc/10274>           RP2  skos:closeMatch
# 2  <http://identifiers.org/hgnc/10274>           RP2  skos:closeMatch
# 3  <http://identifiers.org/hgnc/10288>           RP9  skos:closeMatch
# 4  <http://identifiers.org/hgnc/10457>           RS1  skos:closeMatch
#
#        object_id             object_label   mapping_justification  \
# 0  MONDO:0008377   retinitis pigmentosa 1  semapv:LexicalMatching
# 1  MONDO:0010723   retinitis pigmentosa 2  semapv:LexicalMatching
# 2  MONDO:0100442  RP2-related retinopathy  semapv:LexicalMatching
# 3  MONDO:0008378   retinitis pigmentosa 9  semapv:LexicalMatching
# 4  MONDO:0010725   X-linked retinoschisis  semapv:LexicalMatching
#
#   mapping_tool  confidence subject_match_field     object_match_field  \
# 0       oaklib         0.5          rdfs:label    oio:hasExactSynonym
# 1       oaklib         0.5          rdfs:label    oio:hasExactSynonym
# 2       oaklib         0.5          rdfs:label   oio:hasNarrowSynonym
# 3       oaklib         0.5          rdfs:label    oio:hasExactSynonym
# 4       oaklib         0.5          rdfs:label  oio:hasRelatedSynonym
#
#   match_string
# 0          rp1
# 1          rp2
# 2          rp2
# 3          rp9
# 4          rs1

# %%
condition_mondo_subj = mondo_lexmatch_df.df['subject_id'].str.contains("MONDO")
condition_mondo_obj = mondo_lexmatch_df.df['object_id'].str.contains("MONDO")

non_mondo_subjects_df =  pd.DataFrame(mondo_lexmatch_df.df[(~condition_mondo_subj & condition_mondo_obj)])
mondo_subjects_df = pd.DataFrame(mondo_lexmatch_df.df[(condition_mondo_subj & ~condition_mondo_obj)])

non_mondo_subjects_df.head()
# Out:
#                             subject_id subject_label     predicate_id  \
# 0  <http://identifiers.org/hgnc/10263>           RP1  skos:closeMatch
# 1  <http://identifiers.org/hgnc/10274>           RP2  skos:closeMatch
# 2  <http://identifiers.org/hgnc/10274>           RP2  skos:closeMatch
# 3  <http://identifiers.org/hgnc/10288>           RP9  skos:closeMatch
# 4  <http://identifiers.org/hgnc/10457>           RS1  skos:closeMatch
#
#        object_id             object_label   mapping_justification  \
# 0  MONDO:0008377   retinitis pigmentosa 1  semapv:LexicalMatching
# 1  MONDO:0010723   retinitis pigmentosa 2  semapv:LexicalMatching
# 2  MONDO:0100442  RP2-related retinopathy  semapv:LexicalMatching
# 3  MONDO:0008378   retinitis pigmentosa 9  semapv:LexicalMatching
# 4  MONDO:0010725   X-linked retinoschisis  semapv:LexicalMatching
#
#   mapping_tool  confidence subject_match_field     object_match_field  \
# 0       oaklib         0.5          rdfs:label    oio:hasExactSynonym
# 1       oaklib         0.5          rdfs:label    oio:hasExactSynonym
# 2       oaklib         0.5          rdfs:label   oio:hasNarrowSynonym
# 3       oaklib         0.5          rdfs:label    oio:hasExactSynonym
# 4       oaklib         0.5          rdfs:label  oio:hasRelatedSynonym
#
#   match_string
# 0          rp1
# 1          rp2
# 2          rp2
# 3          rp9
# 4          rs1

# %%
non_mondo_subjects_df.columns
# Out:
# Index(['subject_id', 'subject_label', 'predicate_id', 'object_id',
#        'object_label', 'mapping_justification', 'mapping_tool', 'confidence',
#        'subject_match_field', 'object_match_field', 'match_string'],
#       dtype='object')

# %%
desired_sequence = ['subject_id', 'subject_label', 'predicate_id', 'object_id',
       'object_label', 'mapping_justification', 'mapping_tool', 'confidence',
       'subject_match_field', 'object_match_field', 'match_string']

new_subjects_df = non_mondo_subjects_df.rename(columns={
    'subject_id':'object_id', 
    'subject_label':'object_label',
    'object_id':'subject_id', 
    'object_label':'subject_label',
    'subject_match_field': 'object_match_field',
    'object_match_field': 'subject_match_field'
    
})


new_subjects_df = new_subjects_df[desired_sequence]
new_subjects_df["predicate_id"] = new_subjects_df["predicate_id"].apply(lambda x: flip_predicate(x))
print(len(new_subjects_df))
new_subjects_df.head()
# Out:
# 1177
#       subject_id            subject_label     predicate_id  \
# 0  MONDO:0008377   retinitis pigmentosa 1  skos:closeMatch
# 1  MONDO:0010723   retinitis pigmentosa 2  skos:closeMatch
# 2  MONDO:0100442  RP2-related retinopathy  skos:closeMatch
# 3  MONDO:0008378   retinitis pigmentosa 9  skos:closeMatch
# 4  MONDO:0010725   X-linked retinoschisis  skos:closeMatch
#
#                              object_id object_label   mapping_justification  \
# 0  <http://identifiers.org/hgnc/10263>          RP1  semapv:LexicalMatching
# 1  <http://identifiers.org/hgnc/10274>          RP2  semapv:LexicalMatching
# 2  <http://identifiers.org/hgnc/10274>          RP2  semapv:LexicalMatching
# 3  <http://identifiers.org/hgnc/10288>          RP9  semapv:LexicalMatching
# 4  <http://identifiers.org/hgnc/10457>          RS1  semapv:LexicalMatching
#
#   mapping_tool  confidence    subject_match_field object_match_field  \
# 0       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 1       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 2       oaklib         0.5   oio:hasNarrowSynonym         rdfs:label
# 3       oaklib         0.5    oio:hasExactSynonym         rdfs:label
# 4       oaklib         0.5  oio:hasRelatedSynonym         rdfs:label
#
#   match_string
# 0          rp1
# 1          rp2
# 2          rp2
# 3          rp9
# 4          rs1
